# %%
import sys
import re
import os
import random
from math import log, ceil
import numpy as np
import zlib
import bz2

# %%
log2p = lambda x: int(ceil(log(x,2)))
MAXPATTERNSIZE = 64		# max length of duplicates

def BackExplore(Str, split, Pattern):
	""" Looks for Pattern before split point, as long as coding for duplication is advantageous
		If found, Pattern is replaced by 
			<relative position in History> <pattern length>
		where position and length are coded in standard binary representation
	"""
	PatternLength = len(Pattern)
	# constraint: log(1+<relative position>) + log(1+PatternLength) < PatternLength
	MaxPast = 2 ** (PatternLength - log2p(1+PatternLength)) - 1		# MaxPast > 0 as soon as PL >= 4
	if MaxPast > 0:
		Best = ' ' * PatternLength	# will store best code for duplicate od Pattern
		for shift in range(min(split, MaxPast)):
			if Str[split-shift-PatternLength:split-shift] == Pattern:
				Code = "%s %s" % (bin(shift)[2:], bin(PatternLength)[2:])
				if len(Code) < len(Best):	Best = Code
		if Best.strip(): return Best
	return None

def Encode(Str):
	" detects duplicates and encodes the string accordingly "
	
	Best = (0, 0, ' ' * MAXPATTERNSIZE)	# will store best duplicate (for the code length difference)
	for split in range(len(Str)):	# splitting the string at all successive positions
		for PatternLength in range(MAXPATTERNSIZE, 2, -1):
			Pattern = Str[split:split+PatternLength]
			ActualPL = len(Pattern)	# may differ from PatternLength
			BE = BackExplore(Str, split, Pattern)
			if BE:
				Gain = ActualPL - len(BE)
				if Gain > 1 and Gain > Best[1] - len(Best[2]):
					Best = (split, ActualPL, BE)
	splt, pl, be = Best
	if be.strip():		# duplicate found
		# recursive calls
		Start = Encode(Str[:splt])
		End = Encode(Str[splt+pl:])
		print('pattern %s of length %d is duplicated at location %d' % (Str[splt:splt+pl], pl, splt))
		return ('%s 1 %s %s' % (Start, be, End)).strip()	# the encoded part is prefixed by 1
	# return '0 ' + Str if Str else ''
	return Str

def Decode(EStr):
	" decodes a string in which duplicates have been encoded "
	Chunks = re.split(r'( 1 \d+ \d+)', EStr)	# splitting code chunks, either <NormalStr> or <1 distanceToPattern patternLength>
	Chunks = map(lambda x: x.strip(), Chunks)	# getting rid of surrounding spaces
	Str = ''
	for Ch in list(Chunks):
		if not Ch.startswith('1 '):	Str += Ch	# normal string
		else:	# expected: <1 distanceToPattern patternLength>
			shift = int(Ch.split()[1], 2)
			patternLength = int(Ch.split()[2], 2)
			SL = len(Str)
			Str += Str[SL-shift-patternLength:SL-shift]
	return Str
	
if __name__ == "__main__":	
	print(__doc__)
	if len(sys.argv) > 1:	TestStr = ''.join(sys.argv[1:])	
	else:
		# TestStr = "001010000111110100110100001111101010010001"
		# TestStr = "001010000111110100110100001111101010010000111000011"
		# TestStr = "0101010101010101010101010101010101"
		# TestStr = "0001010110111001101000010111110011011100110110010001011100110001"
		# TestStr = "1100110100110110111110100001000101011101011101101111101111101111100001100110000111100001100110111000"
		Pi = '1001001000011111101101010100010001000010110100011000010001101001100010011000110011000101000101110000000110111'
		# TestStr = Pi
		TestStr = ''.join([str(random.randint(0,1)) for n in range(100) ])	# random sequence
		print('Usage: %s <binary string with duplicates>\n' % os.path.basename(sys.argv[0]))
	ETestStr = Encode(TestStr)
	print('Original:\t%s - length: %d' % (TestStr, len(TestStr)))
	print('Encoded:\t%s - length: %d' % (ETestStr, len(ETestStr.replace(' ',''))))
	DTestStr = Decode(ETestStr)
	print('Decoded:\t%s - %s' % (DTestStr, 'Correct' if DTestStr == TestStr else 'Incorrect'))

__author__ = 'Dessalles'
# Out:
# Automatically created module for IPython interactive environment
# Original:	-f/Users/Marie/Library/Jupyter/runtime/kernel-2478fd2b-eaa9-4449-98ac-f4bc15ee1dac.json - length: 87
# Encoded:	-f/Users/Marie/Library/Jupyter/runtime/kernel-2478fd2b-eaa9-4449-98ac-f4bc15ee1dac.json - length: 87
# Decoded:	-f/Users/Marie/Library/Jupyter/runtime/kernel-2478fd2b-eaa9-4449-98ac-f4bc15ee1dac.json - Correct

# %%
l = Encode('1110011010100111000110011100001101110100100011000101100000100011110000101100111011010011000001100011')
# Out:
# pattern 0011000 of length 7 is duplicated at location 62
# pattern 100111000 of length 9 is duplicated at location 20

# %%
import zlib

TRIALS = 5000	# number of trials to get average

#*******************************************#
# Biased sequence generation                #
#*******************************************#

def BitGen(Probability1):
	" biased coin flipping "
	return 1 * (random.random() < Probability1)
	
def SeqGen(Length, Probability1):
	" generates a biased random binary string "
	return ''.join([str(BitGen(Probability1)) for n in range(Length)])

def SeqCompress(Sequence):
	if type(Sequence) == str:
		Sequence = Sequence.encode('latin-1')	# 'latin-1' =   8 bits ASCII
	CompressedSize = len(zlib.compress(Sequence))
	CompressingFactor = 100-(100*CompressedSize)/len(Sequence)
	return CompressingFactor

	
if __name__ == "__main__":	
	if len(sys.argv) == 3 and sys.argv[1].isdigit() and sys.argv[2].isdigit():
		SequenceLength = int(sys.argv[1])
		Probability = int(sys.argv[2])
		# Since sequence is coded as an ascii sting, even a random sequence get compressed
		# One must subtract the compression factor of a random sequence
		S1 = SeqGen(int(sys.argv[1]), 1)	# constant sequence of same length
		# Compression factors:
		CF1 = SeqCompress(S1)
		CF = 0
		for n in range(TRIALS):	# averaging over several trials
			S0 = SeqGen(int(sys.argv[1]), 0.5)	# unbiased random sequence of same length
			CF0 = SeqCompress(S0)
			S = SeqGen(SequenceLength, Probability/100.0)
			if n < 10:	print('%s %s' % (S[:40], '...' * (SequenceLength > 40)))
			if n == 10:	print('...')
			CF += SeqCompress(S)
		CF /= TRIALS	# average
		print('Compression = %.01f%%' % (100 * (CF - CF0)/(CF1 - CF0)))
	else:
		print("\tUsage: %s <sequence length> <probability of 1s in %%>" % os.path.basename(sys.argv[0]))
		print(__doc__)
# Out:
# 	Usage: ipykernel_launcher.py <sequence length> <probability of 1s in %>
# Automatically created module for IPython interactive environment

# %%
s = SeqGen(1000,0.22)
s =b'1'*1000
s
# Out:
# b'...'

# %%
s1 = Encode(s)
# Out:
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'111111111111111' of length 15 is duplicated at location 15
# pattern b'1111111111111111111111111111111' of length 31 is duplicated at location 31
# pattern b'1111111' of length 7 is duplicated at location 7
# pattern b'11111111111111' of length 14 is duplicated at location 14
# pattern b'11111111111111111111111111111' of length 29 is duplicated at location 29
# pattern b'11111111111111111111111111111111111111111111111111111111111' of length 59 is duplicated at location 59
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63
# pattern b'111111111111111111111111111111111111111111111111111111111111111' of length 63 is duplicated at location 63

# %%
len(s1)/len(s)
# Out:
# 0.514

# %%
Xabs = np.linspace(0, 0.5,10)
s2 = Encode(SeqGen(1000,Xabs))
plt.plot(Xabs, s2)

# %%
#******************************#
# choosing compression method  #
#******************************#
compressor = zlib.compress		# compressor that is used in compression operations
# compressor = bz2.compress		# compressor that is used in compression operations

Bits = ['0', '1']
Bytes = [chr(i) for i in range(256)]		# 256 first chars


#******************************#
# base conversions             #
#******************************#
def BaseChange(Number, BaseSymbols=Bytes):
	""" converts a number from base 10 to another base 
	"""
	Base = len(BaseSymbols)
	result = ''
	Number = int(Number)	# to avoid errors if input is text
	while Number:
		result = BaseSymbols[Number % (Base)] + result	# low-weight digits processed first
		Number //= Base
	return result	# returned as a string

def Base4To16(DNA, Nucleotides='ATGC'):
	"""	converts DNA string with A,T,G,C into base 256
	"""
	Base = list(Nucleotides)
	ByteSequence = ''
	for locus in range(0, len(DNA), 4):
		Hexa = Base.index(DNA[locus])
		Hexa += Base.index(DNA[locus+1])*4
		Hexa += Base.index(DNA[locus+2])*16
		Hexa += Base.index(DNA[locus+3])*64
		ByteSequence += Bytes[Hexa]
	return HexaSequence

	
	
#******************************#
# Compressing sequences        #
#******************************#
	
def Champernowne(N, base=10):
	" computes the Champernowne constant up to N in various bases "
	Champ = ''
	easybases = {2:'b', 8:'o', 10:'', 16:'x'}
	if base in easybases:
		for i in range(N): Champ += ('{0:%s}' % easybases[base]).format(i)
	else:	print('Unsupported base: %d' % base)
	return Champ
	
def compression(TextSample, TextName='', Encoding='latin-1', Verbose=True):
	"""	gets a string compressed and prints compression factor
	"""
	try:	
		if Verbose:	sys.stdout.write("Compressing %s ...\n" % TextSample[:40])
	except UnicodeEncodeError:	pass
	if type(TextSample) == str:
		TextSample = TextSample.encode(Encoding)	# 'latin-1' =   8 bits ASCII
	CompressedSize = len(compressor(TextSample))
	CompressingFactor = 100-(100*CompressedSize)/len(TextSample)
	if Verbose:
		print("%s: size %d reduced to --> %d (compression %.01f%%)" % (TextName, len(TextSample), 
			CompressedSize, CompressingFactor))
	return (CompressedSize, CompressingFactor)
	
  
if __name__ == "__main__":	
	
	##############################
	# Compressing pow(10,i) base 10  #
	##############################
	i = 10000
	print('\nCompressing pow(10,%d) base 10' % i)
	Num = pow(10,i)
	StrNum = str(Num)
	compression(StrNum, "power of ten")

	######################################
	# Compressing pow(256,i) (base 256)  #
	######################################
	i = 10000
	print('\nCompressing pow(256,%d) base 256 represented in bytes' % i)
	Num = pow(256,i)
	StrNum = BaseChange(Num, Bytes)	# mostly null chars
	compression(StrNum, "power of 256")


	#################################
	# Compressing a Random Number   #
	#################################
	i = 10000
	print('\nCompressing a pseudo-Random Number larger than 10^%d represented in bytes' % i)
	Num = random.randint(pow(10,i),pow(10,i+1)-1)
	# Changing base to 256 to use full string expressive power
	StrNum = BaseChange(Num, Bytes)	# converts base 10 into 256
	compression(StrNum, "random number", Encoding='latin-1')
	

	##############################
	# Compressing Pi             #
	##############################
	print('\nCompressing Pi represented in bytes')
	PIDECIMALSFILE = "Pi_decimals.txt"
	try:
		TextSample = open(PIDECIMALSFILE).read()
		TextSample = re.sub(r'[\s\.\,]', '', TextSample)	# gets rid of spaces and punctations
		##### Add relevant line here #######
		(CompSize, CompFactor) = compression(TextSample, "Pi in base 10")
		if CompFactor > 1:	print("Strange: Pi's decimals seem to be compressible !!")
	except IOError:
		print(f"To compress 'Pi', please provide a text file '{PIDECIMALSFILE}' with decimal digits of Pi")
# Out:
# Compressing pow(10,10000) base 10
# Compressing 1000000000000000000000000000000000000000 ...
# power of ten: size 10001 reduced to --> 34 (compression 99.7%)
#
# Compressing pow(256,10000) base 256 represented in bytes
# Compressing  ...
# power of 256: size 10001 reduced to --> 32 (compression 99.7%)
#
# Compressing a pseudo-Random Number larger than 10^10000 represented in bytes
# Compressing MÛ©·· Å5!>Ê ¶ä¸(âï[M+vwkíÐpy¾'E ...
# random number: size 4153 reduced to --> 4164 (compression -0.3%)
#
# Compressing Pi represented in bytes
# Compressing 3141592653589793238462643383279502884197 ...
# Pi in base 10: size 10000 reduced to --> 5089 (compression 49.1%)
# Strange: Pi's decimals seem to be compressible !!

# %%
	##############################
	# Compressing Pi             #
	##############################
	print('\nCompressing Pi represented in bytes')
	PIDECIMALSFILE = "Pi_decimals.txt"
	try:
		TextSample = open(PIDECIMALSFILE).read()
		TextSample = re.sub(r'[\s\.\,]', '', TextSample)	# gets rid of spaces and punctations
		TextSample = BaseChange(TextSample, Bytes)	# converts base 10 into 256
		(CompSize, CompFactor) = compression(TextSample, "Pi in base 256")
		if CompFactor > 1:	print("Strange: Pi's decimals seem to be compressible !!")
	except IOError:
		print(f"To compress 'Pi', please provide a text file '{PIDECIMALSFILE}' with decimal digits of Pi")
# Out:
# Compressing Pi represented in bytes
# ¹S¡Æí2aw¹Õ.>~Ð¦Eü[§oëþ+Ý§6 ...
# Pi in base 256: size 4153 reduced to --> 4164 (compression -0.3%)

# %%
import sys
import os
import zlib


Str = open('./kolmo.txt', 'rb').read().replace(b'\r\n', b' ').replace(b'\r', b' ').replace(b'\n', b' ')
print(len(Str))
for zipIteration in range(1237):
    print('Iteration %d: length = %d' % (zipIteration, len(Str)))
    Str = zlib.compress(Str)
# Out:
# 24895
# Iteration 0: length = 24895
# Iteration 1: length = 8705
# Iteration 2: length = 8716
# Iteration 3: length = 8727
# Iteration 4: length = 8738
# Iteration 5: length = 8749
# Iteration 6: length = 8760
# Iteration 7: length = 8771
# Iteration 8: length = 8782
# Iteration 9: length = 8793
# Iteration 10: length = 8804
# Iteration 11: length = 8815
# Iteration 12: length = 8826
# Iteration 13: length = 8837
# Iteration 14: length = 8848
# Iteration 15: length = 8859
# Iteration 16: length = 8870
# Iteration 17: length = 8881
# Iteration 18: length = 8892
# Iteration 19: length = 8903
# Iteration 20: length = 8912
# Iteration 21: length = 8923
# Iteration 22: length = 8934
# Iteration 23: length = 8945
# Iteration 24: length = 8956
# Iteration 25: length = 8967
# Iteration 26: length = 8978
# Iteration 27: length = 8989
# Iteration 28: length = 9000
# Iteration 29: length = 9011
# Iteration 30: length = 9022
# Iteration 31: length = 9033
# Iteration 32: length = 9044
# Iteration 33: length = 9055
# Iteration 34: length = 9066
# Iteration 35: length = 9077
# Iteration 36: length = 9088
# Iteration 37: length = 9099
# Iteration 38: length = 9110
# Iteration 39: length = 9118
# Iteration 40: length = 9129
# Iteration 41: length = 9140
# Iteration 42: length = 9151
# Iteration 43: length = 9162
# Iteration 44: length = 9173
# Iteration 45: length = 9184
# Iteration 46: length = 9195
# Iteration 47: length = 9206
# Iteration 48: length = 9217
# Iteration 49: length = 9228
# Iteration 50: length = 9239
# Iteration 51: length = 9250
# Iteration 52: length = 9261
# Iteration 53: length = 9272
# Iteration 54: length = 9283
# Iteration 55: length = 9294
# Iteration 56: length = 9305
# Iteration 57: length = 9312
# Iteration 58: length = 9323
# Iteration 59: length = 9334
# Iteration 60: length = 9345
# Iteration 61: length = 9356
# Iteration 62: length = 9367
# Iteration 63: length = 9378
# Iteration 64: length = 9389
# Iteration 65: length = 9400
# Iteration 66: length = 9411
# Iteration 67: length = 9422
# Iteration 68: length = 9433
# Iteration 69: length = 9444
# Iteration 70: length = 9455
# Iteration 71: length = 9466
# Iteration 72: length = 9477
# Iteration 73: length = 9488
# Iteration 74: length = 9499
# Iteration 75: length = 9506
# Iteration 76: length = 9517
# Iteration 77: length = 9528
# Iteration 78: length = 9539
# Iteration 79: length = 9550
# Iteration 80: length = 9561
# Iteration 81: length = 9572
# Iteration 82: length = 9583
# Iteration 83: length = 9594
# Iteration 84: length = 9605
# Iteration 85: length = 9616
# Iteration 86: length = 9627
# Iteration 87: length = 9638
# Iteration 88: length = 9649
# Iteration 89: length = 9660
# Iteration 90: length = 9671
# Iteration 91: length = 9682
# Iteration 92: length = 9693
# Iteration 93: length = 9701
# Iteration 94: length = 9712
# Iteration 95: length = 9723
# Iteration 96: length = 9734
# Iteration 97: length = 9745
# Iteration 98: length = 9756
# Iteration 99: length = 9767
# Iteration 100: length = 9778
# Iteration 101: length = 9789
# Iteration 102: length = 9800
# Iteration 103: length = 9811
# Iteration 104: length = 9822
# Iteration 105: length = 9833
# Iteration 106: length = 9844
# Iteration 107: length = 9855
# Iteration 108: length = 9866
# Iteration 109: length = 9877
# Iteration 110: length = 9888
# Iteration 111: length = 9899
# Iteration 112: length = 9906
# Iteration 113: length = 9917
# Iteration 114: length = 9928
# Iteration 115: length = 9939
# Iteration 116: length = 9950
# Iteration 117: length = 9961
# Iteration 118: length = 9972
# Iteration 119: length = 9983
# Iteration 120: length = 9994
# Iteration 121: length = 10005
# Iteration 122: length = 10016
# Iteration 123: length = 10027
# Iteration 124: length = 10038
# Iteration 125: length = 10049
# Iteration 126: length = 10060
# Iteration 127: length = 10071
# Iteration 128: length = 10082
# Iteration 129: length = 10093
# Iteration 130: length = 10102
# Iteration 131: length = 10113
# Iteration 132: length = 10124
# Iteration 133: length = 10135
# Iteration 134: length = 10146
# Iteration 135: length = 10157
# Iteration 136: length = 10168
# Iteration 137: length = 10179
# Iteration 138: length = 10190
# Iteration 139: length = 10201
# Iteration 140: length = 10212
# Iteration 141: length = 10223
# Iteration 142: length = 10234
# Iteration 143: length = 10245
# Iteration 144: length = 10256
# Iteration 145: length = 10267
# Iteration 146: length = 10278
# Iteration 147: length = 10287
# Iteration 148: length = 10298
# Iteration 149: length = 10309
# Iteration 150: length = 10320
# Iteration 151: length = 10331
# Iteration 152: length = 10342
# Iteration 153: length = 10353
# Iteration 154: length = 10364
# Iteration 155: length = 10375
# Iteration 156: length = 10386
# Iteration 157: length = 10397
# Iteration 158: length = 10408
# Iteration 159: length = 10419
# Iteration 160: length = 10430
# Iteration 161: length = 10441
# Iteration 162: length = 10452
# Iteration 163: length = 10463
# Iteration 164: length = 10472
# Iteration 165: length = 10483
# Iteration 166: length = 10494
# Iteration 167: length = 10505
# Iteration 168: length = 10516
# Iteration 169: length = 10527
# Iteration 170: length = 10538
# Iteration 171: length = 10549
# Iteration 172: length = 10560
# Iteration 173: length = 10571
# Iteration 174: length = 10582
# Iteration 175: length = 10593
# Iteration 176: length = 10604
# Iteration 177: length = 10615
# Iteration 178: length = 10626
# Iteration 179: length = 10637
# Iteration 180: length = 10648
# Iteration 181: length = 10659
# Iteration 182: length = 10667
# Iteration 183: length = 10678
# Iteration 184: length = 10689
# Iteration 185: length = 10700
# Iteration 186: length = 10711
# Iteration 187: length = 10722
# Iteration 188: length = 10733
# Iteration 189: length = 10744
# Iteration 190: length = 10755
# Iteration 191: length = 10766
# Iteration 192: length = 10777
# Iteration 193: length = 10788
# Iteration 194: length = 10799
# Iteration 195: length = 10810
# Iteration 196: length = 10821
# Iteration 197: length = 10832
# Iteration 198: length = 10843
# Iteration 199: length = 10851
# Iteration 200: length = 10862
# Iteration 201: length = 10873
# Iteration 202: length = 10884
# Iteration 203: length = 10895
# Iteration 204: length = 10906
# Iteration 205: length = 10917
# Iteration 206: length = 10928
# Iteration 207: length = 10939
# Iteration 208: length = 10950
# Iteration 209: length = 10961
# Iteration 210: length = 10972
# Iteration 211: length = 10983
# Iteration 212: length = 10994
# Iteration 213: length = 11005
# Iteration 214: length = 11016
# Iteration 215: length = 11025
# Iteration 216: length = 11036
# Iteration 217: length = 11047
# Iteration 218: length = 11058
# Iteration 219: length = 11069
# Iteration 220: length = 11080
# Iteration 221: length = 11091
# Iteration 222: length = 11102
# Iteration 223: length = 11113
# Iteration 224: length = 11124
# Iteration 225: length = 11135
# Iteration 226: length = 11146
# Iteration 227: length = 11157
# Iteration 228: length = 11168
# Iteration 229: length = 11179
# Iteration 230: length = 11190
# Iteration 231: length = 11201
# Iteration 232: length = 11209
# Iteration 233: length = 11220
# Iteration 234: length = 11231
# Iteration 235: length = 11242
# Iteration 236: length = 11253
# Iteration 237: length = 11264
# Iteration 238: length = 11275
# Iteration 239: length = 11286
# Iteration 240: length = 11297
# Iteration 241: length = 11308
# Iteration 242: length = 11319
# Iteration 243: length = 11330
# Iteration 244: length = 11341
# Iteration 245: length = 11352
# Iteration 246: length = 11363
# Iteration 247: length = 11374
# Iteration 248: length = 11385
# Iteration 249: length = 11394
# Iteration 250: length = 11405
# Iteration 251: length = 11416
# Iteration 252: length = 11427
# Iteration 253: length = 11438
# Iteration 254: length = 11449
# Iteration 255: length = 11460
# Iteration 256: length = 11471
# Iteration 257: length = 11482
# Iteration 258: length = 11493
# Iteration 259: length = 11504
# Iteration 260: length = 11515
# Iteration 261: length = 11526
# Iteration 262: length = 11537
# Iteration 263: length = 11548
# Iteration 264: length = 11559
# Iteration 265: length = 11570
# Iteration 266: length = 11577
# Iteration 267: length = 11588
# Iteration 268: length = 11599
# Iteration 269: length = 11610
# Iteration 270: length = 11621
# Iteration 271: length = 11632
# Iteration 272: length = 11643
# Iteration 273: length = 11654
# Iteration 274: length = 11665
# Iteration 275: length = 11676
# Iteration 276: length = 11687
# Iteration 277: length = 11698
# Iteration 278: length = 11709
# Iteration 279: length = 11720
# Iteration 280: length = 11731
# Iteration 281: length = 11742
# Iteration 282: length = 11753
# Iteration 283: length = 11760
# Iteration 284: length = 11771
# Iteration 285: length = 11782
# Iteration 286: length = 11793
# Iteration 287: length = 11804
# Iteration 288: length = 11815
# Iteration 289: length = 11826
# Iteration 290: length = 11837
# Iteration 291: length = 11848
# Iteration 292: length = 11859
# Iteration 293: length = 11870
# Iteration 294: length = 11881
# Iteration 295: length = 11892
# Iteration 296: length = 11903
# Iteration 297: length = 11914
# Iteration 298: length = 11925
# Iteration 299: length = 11936
# Iteration 300: length = 11945
# Iteration 301: length = 11956
# Iteration 302: length = 11967
# Iteration 303: length = 11978
# Iteration 304: length = 11989
# Iteration 305: length = 12000
# Iteration 306: length = 12011
# Iteration 307: length = 12022
# Iteration 308: length = 12033
# Iteration 309: length = 12044
# Iteration 310: length = 12055
# Iteration 311: length = 12066
# Iteration 312: length = 12077
# Iteration 313: length = 12088
# Iteration 314: length = 12099
# Iteration 315: length = 12110
# Iteration 316: length = 12121
# Iteration 317: length = 12129
# Iteration 318: length = 12140
# Iteration 319: length = 12151
# Iteration 320: length = 12162
# Iteration 321: length = 12173
# Iteration 322: length = 12184
# Iteration 323: length = 12195
# Iteration 324: length = 12206
# Iteration 325: length = 12217
# Iteration 326: length = 12228
# Iteration 327: length = 12239
# Iteration 328: length = 12250
# Iteration 329: length = 12261
# Iteration 330: length = 12272
# Iteration 331: length = 12283
# Iteration 332: length = 12294
# Iteration 333: length = 12305
# Iteration 334: length = 12316
# Iteration 335: length = 12325
# Iteration 336: length = 12336
# Iteration 337: length = 12347
# Iteration 338: length = 12358
# Iteration 339: length = 12369
# Iteration 340: length = 12380
# Iteration 341: length = 12391
# Iteration 342: length = 12402
# Iteration 343: length = 12413
# Iteration 344: length = 12424
# Iteration 345: length = 12435
# Iteration 346: length = 12446
# Iteration 347: length = 12457
# Iteration 348: length = 12468
# Iteration 349: length = 12479
# Iteration 350: length = 12490
# Iteration 351: length = 12497
# Iteration 352: length = 12508
# Iteration 353: length = 12519
# Iteration 354: length = 12530
# Iteration 355: length = 12541
# Iteration 356: length = 12552
# Iteration 357: length = 12563
# Iteration 358: length = 12574
# Iteration 359: length = 12585
# Iteration 360: length = 12596
# Iteration 361: length = 12607
# Iteration 362: length = 12618
# Iteration 363: length = 12629
# Iteration 364: length = 12640
# Iteration 365: length = 12651
# Iteration 366: length = 12662
# Iteration 367: length = 12673
# Iteration 368: length = 12684
# Iteration 369: length = 12691
# Iteration 370: length = 12702
# Iteration 371: length = 12713
# Iteration 372: length = 12724
# Iteration 373: length = 12735
# Iteration 374: length = 12746
# Iteration 375: length = 12757
# Iteration 376: length = 12768
# Iteration 377: length = 12779
# Iteration 378: length = 12790
# Iteration 379: length = 12801
# Iteration 380: length = 12812
# Iteration 381: length = 12823
# Iteration 382: length = 12834
# Iteration 383: length = 12845
# Iteration 384: length = 12856
# Iteration 385: length = 12865
# Iteration 386: length = 12876
# Iteration 387: length = 12887
# Iteration 388: length = 12898
# Iteration 389: length = 12909
# Iteration 390: length = 12920
# Iteration 391: length = 12931
# Iteration 392: length = 12942
# Iteration 393: length = 12953
# Iteration 394: length = 12964
# Iteration 395: length = 12975
# Iteration 396: length = 12986
# Iteration 397: length = 12997
# Iteration 398: length = 13008
# Iteration 399: length = 13019
# Iteration 400: length = 13030
# Iteration 401: length = 13041
# Iteration 402: length = 13050
# Iteration 403: length = 13061
# Iteration 404: length = 13072
# Iteration 405: length = 13083
# Iteration 406: length = 13094
# Iteration 407: length = 13105
# Iteration 408: length = 13116
# Iteration 409: length = 13127
# Iteration 410: length = 13138
# Iteration 411: length = 13149
# Iteration 412: length = 13160
# Iteration 413: length = 13171
# Iteration 414: length = 13182
# Iteration 415: length = 13193
# Iteration 416: length = 13204
# Iteration 417: length = 13215
# Iteration 418: length = 13224
# Iteration 419: length = 13235
# Iteration 420: length = 13246
# Iteration 421: length = 13257
# Iteration 422: length = 13268
# Iteration 423: length = 13279
# Iteration 424: length = 13290
# Iteration 425: length = 13301
# Iteration 426: length = 13312
# Iteration 427: length = 13323
# Iteration 428: length = 13334
# Iteration 429: length = 13345
# Iteration 430: length = 13356
# Iteration 431: length = 13367
# Iteration 432: length = 13378
# Iteration 433: length = 13389
# Iteration 434: length = 13400
# Iteration 435: length = 13407
# Iteration 436: length = 13418
# Iteration 437: length = 13429
# Iteration 438: length = 13440
# Iteration 439: length = 13451
# Iteration 440: length = 13462
# Iteration 441: length = 13473
# Iteration 442: length = 13484
# Iteration 443: length = 13495
# Iteration 444: length = 13506
# Iteration 445: length = 13517
# Iteration 446: length = 13528
# Iteration 447: length = 13539
# Iteration 448: length = 13550
# Iteration 449: length = 13561
# Iteration 450: length = 13572
# Iteration 451: length = 13581
# Iteration 452: length = 13592
# Iteration 453: length = 13603
# Iteration 454: length = 13614
# Iteration 455: length = 13625
# Iteration 456: length = 13636
# Iteration 457: length = 13647
# Iteration 458: length = 13658
# Iteration 459: length = 13669
# Iteration 460: length = 13680
# Iteration 461: length = 13691
# Iteration 462: length = 13702
# Iteration 463: length = 13713
# Iteration 464: length = 13724
# Iteration 465: length = 13735
# Iteration 466: length = 13744
# Iteration 467: length = 13755
# Iteration 468: length = 13766
# Iteration 469: length = 13777
# Iteration 470: length = 13788
# Iteration 471: length = 13799
# Iteration 472: length = 13810
# Iteration 473: length = 13821
# Iteration 474: length = 13832
# Iteration 475: length = 13843
# Iteration 476: length = 13854
# Iteration 477: length = 13865
# Iteration 478: length = 13876
# Iteration 479: length = 13887
# Iteration 480: length = 13898
# Iteration 481: length = 13909
# Iteration 482: length = 13920
# Iteration 483: length = 13927
# Iteration 484: length = 13938
# Iteration 485: length = 13949
# Iteration 486: length = 13960
# Iteration 487: length = 13971
# Iteration 488: length = 13982
# Iteration 489: length = 13993
# Iteration 490: length = 14004
# Iteration 491: length = 14015
# Iteration 492: length = 14026
# Iteration 493: length = 14037
# Iteration 494: length = 14048
# Iteration 495: length = 14059
# Iteration 496: length = 14070
# Iteration 497: length = 14081
# Iteration 498: length = 14092
# Iteration 499: length = 14103
# Iteration 500: length = 14112
# Iteration 501: length = 14123
# Iteration 502: length = 14134
# Iteration 503: length = 14145
# Iteration 504: length = 14156
# Iteration 505: length = 14167
# Iteration 506: length = 14178
# Iteration 507: length = 14189
# Iteration 508: length = 14200
# Iteration 509: length = 14211
# Iteration 510: length = 14222
# Iteration 511: length = 14233
# Iteration 512: length = 14244
# Iteration 513: length = 14255
# Iteration 514: length = 14266
# Iteration 515: length = 14277
# Iteration 516: length = 14288
# Iteration 517: length = 14296
# Iteration 518: length = 14307
# Iteration 519: length = 14318
# Iteration 520: length = 14329
# Iteration 521: length = 14340
# Iteration 522: length = 14351
# Iteration 523: length = 14362
# Iteration 524: length = 14373
# Iteration 525: length = 14384
# Iteration 526: length = 14395
# Iteration 527: length = 14406
# Iteration 528: length = 14417
# Iteration 529: length = 14428
# Iteration 530: length = 14439
# Iteration 531: length = 14450
# Iteration 532: length = 14461
# Iteration 533: length = 14472
# Iteration 534: length = 14483
# Iteration 535: length = 14492
# Iteration 536: length = 14503
# Iteration 537: length = 14514
# Iteration 538: length = 14525
# Iteration 539: length = 14536
# Iteration 540: length = 14547
# Iteration 541: length = 14558
# Iteration 542: length = 14569
# Iteration 543: length = 14580
# Iteration 544: length = 14591
# Iteration 545: length = 14602
# Iteration 546: length = 14613
# Iteration 547: length = 14624
# Iteration 548: length = 14635
# Iteration 549: length = 14646
# Iteration 550: length = 14657
# Iteration 551: length = 14668
# Iteration 552: length = 14676
# Iteration 553: length = 14687
# Iteration 554: length = 14698
# Iteration 555: length = 14709
# Iteration 556: length = 14720
# Iteration 557: length = 14731
# Iteration 558: length = 14742
# Iteration 559: length = 14753
# Iteration 560: length = 14764
# Iteration 561: length = 14775
# Iteration 562: length = 14786
# Iteration 563: length = 14797
# Iteration 564: length = 14808
# Iteration 565: length = 14819
# Iteration 566: length = 14830
# Iteration 567: length = 14838
# Iteration 568: length = 14849
# Iteration 569: length = 14860
# Iteration 570: length = 14871
# Iteration 571: length = 14882
# Iteration 572: length = 14893
# Iteration 573: length = 14904
# Iteration 574: length = 14915
# Iteration 575: length = 14926
# Iteration 576: length = 14937
# Iteration 577: length = 14948
# Iteration 578: length = 14959
# Iteration 579: length = 14970
# Iteration 580: length = 14981
# Iteration 581: length = 14992
# Iteration 582: length = 15003
# Iteration 583: length = 15014
# Iteration 584: length = 15022
# Iteration 585: length = 15033
# Iteration 586: length = 15044
# Iteration 587: length = 15055
# Iteration 588: length = 15066
# Iteration 589: length = 15077
# Iteration 590: length = 15088
# Iteration 591: length = 15099
# Iteration 592: length = 15110
# Iteration 593: length = 15121
# Iteration 594: length = 15132
# Iteration 595: length = 15143
# Iteration 596: length = 15154
# Iteration 597: length = 15165
# Iteration 598: length = 15176
# Iteration 599: length = 15187
# Iteration 600: length = 15196
# Iteration 601: length = 15207
# Iteration 602: length = 15218
# Iteration 603: length = 15229
# Iteration 604: length = 15240
# Iteration 605: length = 15251
# Iteration 606: length = 15262
# Iteration 607: length = 15273
# Iteration 608: length = 15284
# Iteration 609: length = 15295
# Iteration 610: length = 15306
# Iteration 611: length = 15317
# Iteration 612: length = 15328
# Iteration 613: length = 15339
# Iteration 614: length = 15350
# Iteration 615: length = 15361
# Iteration 616: length = 15370
# Iteration 617: length = 15381
# Iteration 618: length = 15392
# Iteration 619: length = 15403
# Iteration 620: length = 15414
# Iteration 621: length = 15425
# Iteration 622: length = 15436
# Iteration 623: length = 15447
# Iteration 624: length = 15458
# Iteration 625: length = 15469
# Iteration 626: length = 15480
# Iteration 627: length = 15491
# Iteration 628: length = 15502
# Iteration 629: length = 15513
# Iteration 630: length = 15524
# Iteration 631: length = 15535
# Iteration 632: length = 15546
# Iteration 633: length = 15553
# Iteration 634: length = 15564
# Iteration 635: length = 15575
# Iteration 636: length = 15586
# Iteration 637: length = 15597
# Iteration 638: length = 15608
# Iteration 639: length = 15619
# Iteration 640: length = 15630
# Iteration 641: length = 15641
# Iteration 642: length = 15652
# Iteration 643: length = 15663
# Iteration 644: length = 15674
# Iteration 645: length = 15685
# Iteration 646: length = 15696
# Iteration 647: length = 15707
# Iteration 648: length = 15718
# Iteration 649: length = 15729
# Iteration 650: length = 15738
# Iteration 651: length = 15749
# Iteration 652: length = 15760
# Iteration 653: length = 15771
# Iteration 654: length = 15782
# Iteration 655: length = 15793
# Iteration 656: length = 15804
# Iteration 657: length = 15815
# Iteration 658: length = 15826
# Iteration 659: length = 15837
# Iteration 660: length = 15848
# Iteration 661: length = 15859
# Iteration 662: length = 15870
# Iteration 663: length = 15881
# Iteration 664: length = 15892
# Iteration 665: length = 15903
# Iteration 666: length = 15914
# Iteration 667: length = 15925
# Iteration 668: length = 15933
# Iteration 669: length = 15944
# Iteration 670: length = 15955
# Iteration 671: length = 15966
# Iteration 672: length = 15977
# Iteration 673: length = 15988
# Iteration 674: length = 15999
# Iteration 675: length = 16010
# Iteration 676: length = 16021
# Iteration 677: length = 16032
# Iteration 678: length = 16043
# Iteration 679: length = 16054
# Iteration 680: length = 16065
# Iteration 681: length = 16076
# Iteration 682: length = 16087
# Iteration 683: length = 16098
# Iteration 684: length = 16106
# Iteration 685: length = 16117
# Iteration 686: length = 16128
# Iteration 687: length = 16139
# Iteration 688: length = 16150
# Iteration 689: length = 16161
# Iteration 690: length = 16172
# Iteration 691: length = 16183
# Iteration 692: length = 16194
# Iteration 693: length = 16205
# Iteration 694: length = 16216
# Iteration 695: length = 16227
# Iteration 696: length = 16238
# Iteration 697: length = 16249
# Iteration 698: length = 16260
# Iteration 699: length = 16271
# Iteration 700: length = 16282
# Iteration 701: length = 16293
# Iteration 702: length = 16300
# Iteration 703: length = 16311
# Iteration 704: length = 16322
# Iteration 705: length = 16333
# Iteration 706: length = 16344
# Iteration 707: length = 16355
# Iteration 708: length = 16366
# Iteration 709: length = 16377
# Iteration 710: length = 16388
# Iteration 711: length = 16399
# Iteration 712: length = 16410
# Iteration 713: length = 16421
# Iteration 714: length = 16432
# Iteration 715: length = 16445
# Iteration 716: length = 16458
# Iteration 717: length = 16472
# Iteration 718: length = 16486
# Iteration 719: length = 16502
# Iteration 720: length = 16515
# Iteration 721: length = 16531
# Iteration 722: length = 16547
# Iteration 723: length = 16563
# Iteration 724: length = 16579
# Iteration 725: length = 16595
# Iteration 726: length = 16611
# Iteration 727: length = 16627
# Iteration 728: length = 16643
# Iteration 729: length = 16659
# Iteration 730: length = 16675
# Iteration 731: length = 16691
# Iteration 732: length = 16707
# Iteration 733: length = 16723
# Iteration 734: length = 16739
# Iteration 735: length = 16755
# Iteration 736: length = 16767
# Iteration 737: length = 16783
# Iteration 738: length = 16799
# Iteration 739: length = 16815
# Iteration 740: length = 16831
# Iteration 741: length = 16847
# Iteration 742: length = 16863
# Iteration 743: length = 16879
# Iteration 744: length = 16895
# Iteration 745: length = 16911
# Iteration 746: length = 16927
# Iteration 747: length = 16943
# Iteration 748: length = 16959
# Iteration 749: length = 16973
# Iteration 750: length = 16989
# Iteration 751: length = 17005
# Iteration 752: length = 17021
# Iteration 753: length = 17037
# Iteration 754: length = 17053
# Iteration 755: length = 17069
# Iteration 756: length = 17085
# Iteration 757: length = 17101
# Iteration 758: length = 17117
# Iteration 759: length = 17133
# Iteration 760: length = 17149
# Iteration 761: length = 17165
# Iteration 762: length = 17181
# Iteration 763: length = 17197
# Iteration 764: length = 17211
# Iteration 765: length = 17227
# Iteration 766: length = 17243
# Iteration 767: length = 17259
# Iteration 768: length = 17275
# Iteration 769: length = 17291
# Iteration 770: length = 17307
# Iteration 771: length = 17323
# Iteration 772: length = 17339
# Iteration 773: length = 17355
# Iteration 774: length = 17371
# Iteration 775: length = 17387
# Iteration 776: length = 17403
# Iteration 777: length = 17419
# Iteration 778: length = 17435
# Iteration 779: length = 17451
# Iteration 780: length = 17467
# Iteration 781: length = 17483
# Iteration 782: length = 17495
# Iteration 783: length = 17511
# Iteration 784: length = 17527
# Iteration 785: length = 17543
# Iteration 786: length = 17559
# Iteration 787: length = 17575
# Iteration 788: length = 17591
# Iteration 789: length = 17607
# Iteration 790: length = 17623
# Iteration 791: length = 17639
# Iteration 792: length = 17655
# Iteration 793: length = 17671
# Iteration 794: length = 17687
# Iteration 795: length = 17703
# Iteration 796: length = 17717
# Iteration 797: length = 17733
# Iteration 798: length = 17745
# Iteration 799: length = 17761
# Iteration 800: length = 17777
# Iteration 801: length = 17793
# Iteration 802: length = 17809
# Iteration 803: length = 17825
# Iteration 804: length = 17841
# Iteration 805: length = 17857
# Iteration 806: length = 17873
# Iteration 807: length = 17889
# Iteration 808: length = 17905
# Iteration 809: length = 17921
# Iteration 810: length = 17937
# Iteration 811: length = 17953
# Iteration 812: length = 17966
# Iteration 813: length = 17982
# Iteration 814: length = 17998
# Iteration 815: length = 18014
# Iteration 816: length = 18030
# Iteration 817: length = 18046
# Iteration 818: length = 18062
# Iteration 819: length = 18078
# Iteration 820: length = 18094
# Iteration 821: length = 18110
# Iteration 822: length = 18126
# Iteration 823: length = 18142
# Iteration 824: length = 18158
# Iteration 825: length = 18174
# Iteration 826: length = 18190
# Iteration 827: length = 18206
# Iteration 828: length = 18218
# Iteration 829: length = 18234
# Iteration 830: length = 18250
# Iteration 831: length = 18266
# Iteration 832: length = 18282
# Iteration 833: length = 18298
# Iteration 834: length = 18314
# Iteration 835: length = 18330
# Iteration 836: length = 18346
# Iteration 837: length = 18362
# Iteration 838: length = 18378
# Iteration 839: length = 18394
# Iteration 840: length = 18410
# Iteration 841: length = 18426
# Iteration 842: length = 18440
# Iteration 843: length = 18456
# Iteration 844: length = 18472
# Iteration 845: length = 18488
# Iteration 846: length = 18504
# Iteration 847: length = 18520
# Iteration 848: length = 18536
# Iteration 849: length = 18552
# Iteration 850: length = 18568
# Iteration 851: length = 18584
# Iteration 852: length = 18600
# Iteration 853: length = 18616
# Iteration 854: length = 18632
# Iteration 855: length = 18648
# Iteration 856: length = 18664
# Iteration 857: length = 18680
# Iteration 858: length = 18693
# Iteration 859: length = 18709
# Iteration 860: length = 18725
# Iteration 861: length = 18741
# Iteration 862: length = 18757
# Iteration 863: length = 18773
# Iteration 864: length = 18789
# Iteration 865: length = 18805
# Iteration 866: length = 18821
# Iteration 867: length = 18837
# Iteration 868: length = 18853
# Iteration 869: length = 18869
# Iteration 870: length = 18885
# Iteration 871: length = 18901
# Iteration 872: length = 18917
# Iteration 873: length = 18929
# Iteration 874: length = 18945
# Iteration 875: length = 18961
# Iteration 876: length = 18977
# Iteration 877: length = 18993
# Iteration 878: length = 19009
# Iteration 879: length = 19025
# Iteration 880: length = 19041
# Iteration 881: length = 19057
# Iteration 882: length = 19073
# Iteration 883: length = 19089
# Iteration 884: length = 19105
# Iteration 885: length = 19121
# Iteration 886: length = 19137
# Iteration 887: length = 19153
# Iteration 888: length = 19165
# Iteration 889: length = 19181
# Iteration 890: length = 19197
# Iteration 891: length = 19213
# Iteration 892: length = 19229
# Iteration 893: length = 19243
# Iteration 894: length = 19259
# Iteration 895: length = 19275
# Iteration 896: length = 19291
# Iteration 897: length = 19307
# Iteration 898: length = 19323
# Iteration 899: length = 19339
# Iteration 900: length = 19355
# Iteration 901: length = 19371
# Iteration 902: length = 19383
# Iteration 903: length = 19399
# Iteration 904: length = 19415
# Iteration 905: length = 19431
# Iteration 906: length = 19447
# Iteration 907: length = 19463
# Iteration 908: length = 19479
# Iteration 909: length = 19495
# Iteration 910: length = 19511
# Iteration 911: length = 19527
# Iteration 912: length = 19543
# Iteration 913: length = 19559
# Iteration 914: length = 19575
# Iteration 915: length = 19588
# Iteration 916: length = 19604
# Iteration 917: length = 19620
# Iteration 918: length = 19636
# Iteration 919: length = 19652
# Iteration 920: length = 19668
# Iteration 921: length = 19684
# Iteration 922: length = 19700
# Iteration 923: length = 19716
# Iteration 924: length = 19732
# Iteration 925: length = 19748
# Iteration 926: length = 19764
# Iteration 927: length = 19780
# Iteration 928: length = 19796
# Iteration 929: length = 19812
# Iteration 930: length = 19825
# Iteration 931: length = 19841
# Iteration 932: length = 19857
# Iteration 933: length = 19873
# Iteration 934: length = 19889
# Iteration 935: length = 19905
# Iteration 936: length = 19921
# Iteration 937: length = 19937
# Iteration 938: length = 19953
# Iteration 939: length = 19969
# Iteration 940: length = 19985
# Iteration 941: length = 20001
# Iteration 942: length = 20017
# Iteration 943: length = 20033
# Iteration 944: length = 20045
# Iteration 945: length = 20061
# Iteration 946: length = 20077
# Iteration 947: length = 20093
# Iteration 948: length = 20109
# Iteration 949: length = 20125
# Iteration 950: length = 20141
# Iteration 951: length = 20157
# Iteration 952: length = 20173
# Iteration 953: length = 20189
# Iteration 954: length = 20205
# Iteration 955: length = 20221
# Iteration 956: length = 20237
# Iteration 957: length = 20253
# Iteration 958: length = 20265
# Iteration 959: length = 20281
# Iteration 960: length = 20297
# Iteration 961: length = 20313
# Iteration 962: length = 20329
# Iteration 963: length = 20345
# Iteration 964: length = 20361
# Iteration 965: length = 20377
# Iteration 966: length = 20393
# Iteration 967: length = 20409
# Iteration 968: length = 20425
# Iteration 969: length = 20441
# Iteration 970: length = 20457
# Iteration 971: length = 20470
# Iteration 972: length = 20486
# Iteration 973: length = 20502
# Iteration 974: length = 20518
# Iteration 975: length = 20534
# Iteration 976: length = 20550
# Iteration 977: length = 20566
# Iteration 978: length = 20582
# Iteration 979: length = 20598
# Iteration 980: length = 20614
# Iteration 981: length = 20630
# Iteration 982: length = 20646
# Iteration 983: length = 20662
# Iteration 984: length = 20675
# Iteration 985: length = 20691
# Iteration 986: length = 20707
# Iteration 987: length = 20723
# Iteration 988: length = 20739
# Iteration 989: length = 20755
# Iteration 990: length = 20771
# Iteration 991: length = 20787
# Iteration 992: length = 20803
# Iteration 993: length = 20819
# Iteration 994: length = 20835
# Iteration 995: length = 20851
# Iteration 996: length = 20867
# Iteration 997: length = 20879
# Iteration 998: length = 20895
# Iteration 999: length = 20911
# Iteration 1000: length = 20927
# Iteration 1001: length = 20943
# Iteration 1002: length = 20959
# Iteration 1003: length = 20975
# Iteration 1004: length = 20991
# Iteration 1005: length = 21007
# Iteration 1006: length = 21023
# Iteration 1007: length = 21039
# Iteration 1008: length = 21055
# Iteration 1009: length = 21071
# Iteration 1010: length = 21087
# Iteration 1011: length = 21103
# Iteration 1012: length = 21115
# Iteration 1013: length = 21131
# Iteration 1014: length = 21147
# Iteration 1015: length = 21163
# Iteration 1016: length = 21179
# Iteration 1017: length = 21195
# Iteration 1018: length = 21211
# Iteration 1019: length = 21227
# Iteration 1020: length = 21243
# Iteration 1021: length = 21259
# Iteration 1022: length = 21275
# Iteration 1023: length = 21291
# Iteration 1024: length = 21305
# Iteration 1025: length = 21321
# Iteration 1026: length = 21332
# Iteration 1027: length = 21348
# Iteration 1028: length = 21364
# Iteration 1029: length = 21380
# Iteration 1030: length = 21396
# Iteration 1031: length = 21412
# Iteration 1032: length = 21428
# Iteration 1033: length = 21444
# Iteration 1034: length = 21460
# Iteration 1035: length = 21476
# Iteration 1036: length = 21492
# Iteration 1037: length = 21508
# Iteration 1038: length = 21524
# Iteration 1039: length = 21540
# Iteration 1040: length = 21552
# Iteration 1041: length = 21568
# Iteration 1042: length = 21584
# Iteration 1043: length = 21600
# Iteration 1044: length = 21616
# Iteration 1045: length = 21632
# Iteration 1046: length = 21648
# Iteration 1047: length = 21664
# Iteration 1048: length = 21680
# Iteration 1049: length = 21696
# Iteration 1050: length = 21712
# Iteration 1051: length = 21728
# Iteration 1052: length = 21741
# Iteration 1053: length = 21757
# Iteration 1054: length = 21773
# Iteration 1055: length = 21789
# Iteration 1056: length = 21805
# Iteration 1057: length = 21821
# Iteration 1058: length = 21837
# Iteration 1059: length = 21853
# Iteration 1060: length = 21869
# Iteration 1061: length = 21885
# Iteration 1062: length = 21901
# Iteration 1063: length = 21917
# Iteration 1064: length = 21933
# Iteration 1065: length = 21949
# Iteration 1066: length = 21961
# Iteration 1067: length = 21977
# Iteration 1068: length = 21993
# Iteration 1069: length = 22009
# Iteration 1070: length = 22025
# Iteration 1071: length = 22041
# Iteration 1072: length = 22057
# Iteration 1073: length = 22073
# Iteration 1074: length = 22089
# Iteration 1075: length = 22105
# Iteration 1076: length = 22121
# Iteration 1077: length = 22137
# Iteration 1078: length = 22153
# Iteration 1079: length = 22169
# Iteration 1080: length = 22185
# Iteration 1081: length = 22201
# Iteration 1082: length = 22214
# Iteration 1083: length = 22230
# Iteration 1084: length = 22246
# Iteration 1085: length = 22262
# Iteration 1086: length = 22278
# Iteration 1087: length = 22294
# Iteration 1088: length = 22310
# Iteration 1089: length = 22326
# Iteration 1090: length = 22342
# Iteration 1091: length = 22358
# Iteration 1092: length = 22374
# Iteration 1093: length = 22390
# Iteration 1094: length = 22406
# Iteration 1095: length = 22422
# Iteration 1096: length = 22434
# Iteration 1097: length = 22450
# Iteration 1098: length = 22466
# Iteration 1099: length = 22482
# Iteration 1100: length = 22498
# Iteration 1101: length = 22514
# Iteration 1102: length = 22530
# Iteration 1103: length = 22546
# Iteration 1104: length = 22562
# Iteration 1105: length = 22578
# Iteration 1106: length = 22594
# Iteration 1107: length = 22610
# Iteration 1108: length = 22626
# Iteration 1109: length = 22638
# Iteration 1110: length = 22654
# Iteration 1111: length = 22670
# Iteration 1112: length = 22686
# Iteration 1113: length = 22702
# Iteration 1114: length = 22718
# Iteration 1115: length = 22734
# Iteration 1116: length = 22750
# Iteration 1117: length = 22766
# Iteration 1118: length = 22782
# Iteration 1119: length = 22798
# Iteration 1120: length = 22814
# Iteration 1121: length = 22830
# Iteration 1122: length = 22846
# Iteration 1123: length = 22862
# Iteration 1124: length = 22876
# Iteration 1125: length = 22892
# Iteration 1126: length = 22908
# Iteration 1127: length = 22924
# Iteration 1128: length = 22940
# Iteration 1129: length = 22956
# Iteration 1130: length = 22972
# Iteration 1131: length = 22988
# Iteration 1132: length = 23004
# Iteration 1133: length = 23020
# Iteration 1134: length = 23036
# Iteration 1135: length = 23052
# Iteration 1136: length = 23068
# Iteration 1137: length = 23084
# Iteration 1138: length = 23096
# Iteration 1139: length = 23112
# Iteration 1140: length = 23128
# Iteration 1141: length = 23144
# Iteration 1142: length = 23160
# Iteration 1143: length = 23176
# Iteration 1144: length = 23192
# Iteration 1145: length = 23208
# Iteration 1146: length = 23224
# Iteration 1147: length = 23240
# Iteration 1148: length = 23256
# Iteration 1149: length = 23272
# Iteration 1150: length = 23288
# Iteration 1151: length = 23304
# Iteration 1152: length = 23320
# Iteration 1153: length = 23333
# Iteration 1154: length = 23349
# Iteration 1155: length = 23365
# Iteration 1156: length = 23381
# Iteration 1157: length = 23397
# Iteration 1158: length = 23413
# Iteration 1159: length = 23429
# Iteration 1160: length = 23445
# Iteration 1161: length = 23461
# Iteration 1162: length = 23477
# Iteration 1163: length = 23493
# Iteration 1164: length = 23509
# Iteration 1165: length = 23525
# Iteration 1166: length = 23537
# Iteration 1167: length = 23553
# Iteration 1168: length = 23569
# Iteration 1169: length = 23585
# Iteration 1170: length = 23601
# Iteration 1171: length = 23617
# Iteration 1172: length = 23633
# Iteration 1173: length = 23649
# Iteration 1174: length = 23665
# Iteration 1175: length = 23681
# Iteration 1176: length = 23697
# Iteration 1177: length = 23713
# Iteration 1178: length = 23729
# Iteration 1179: length = 23745
# Iteration 1180: length = 23761
# Iteration 1181: length = 23777
# Iteration 1182: length = 23793
# Iteration 1183: length = 23805
# Iteration 1184: length = 23821
# Iteration 1185: length = 23837
# Iteration 1186: length = 23853
# Iteration 1187: length = 23869
# Iteration 1188: length = 23885
# Iteration 1189: length = 23901
# Iteration 1190: length = 23917
# Iteration 1191: length = 23933
# Iteration 1192: length = 23949
# Iteration 1193: length = 23965
# Iteration 1194: length = 23981
# Iteration 1195: length = 23997
# Iteration 1196: length = 24013
# Iteration 1197: length = 24029
# Iteration 1198: length = 24045
# Iteration 1199: length = 24061
# Iteration 1200: length = 24073
# Iteration 1201: length = 24089
# Iteration 1202: length = 24105
# Iteration 1203: length = 24121
# Iteration 1204: length = 24137
# Iteration 1205: length = 24153
# Iteration 1206: length = 24169
# Iteration 1207: length = 24185
# Iteration 1208: length = 24201
# Iteration 1209: length = 24217
# Iteration 1210: length = 24233
# Iteration 1211: length = 24249
# Iteration 1212: length = 24263
# Iteration 1213: length = 24279
# Iteration 1214: length = 24295
# Iteration 1215: length = 24306
# Iteration 1216: length = 24322
# Iteration 1217: length = 24338
# Iteration 1218: length = 24354
# Iteration 1219: length = 24370
# Iteration 1220: length = 24386
# Iteration 1221: length = 24402
# Iteration 1222: length = 24418
# Iteration 1223: length = 24434
# Iteration 1224: length = 24450
# Iteration 1225: length = 24466
# Iteration 1226: length = 24482
# Iteration 1227: length = 24498
# Iteration 1228: length = 24514
# Iteration 1229: length = 24527
# Iteration 1230: length = 24543
# Iteration 1231: length = 24559
# Iteration 1232: length = 24575
# Iteration 1233: length = 24591
# Iteration 1234: length = 24607
# Iteration 1235: length = 24623
# Iteration 1236: length = 24639

# %%
fr = 5540000000/(2*10**12)

# %%
np.log(1/fr)
# Out:
# 5.88890795878289

# %%
# book
fb = 14240000000/(2*10**12)
np.log(1/fb)
# Out:
# 4.944847553558253

# %%
# calligraphy
fc = 202000000/(2*10**12)
np.log(1/fc)
# Out:
# 9.200390041123015

# %%
# echitruc
fe = 811000/(2*10**12)
np.log(1/fe)
# Out:
# 14.718144963390943

# %%
un,deux,trois,quatre = 8247, 10793, 2151, 2829

# %%
un_deux = 18022
trois_quatre = 4352

# %%
NCD_12 = 1 - (un_deux - un) / deux

# %%
NCD_34 = 1 - (trois_quatre - trois) / quatre

# %%
NCD_12 - NCD_34
# Out:
# -0.127666174844548
