# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

# %%
xtrain = pd.read_csv("valeo_xtrain.csv")
print(xtrain.shape)
xtrain.head()
# Out:
# (27586, 27)
#    START2_OP020_V_1angle  START2_OP020_V_1torque  START2_OP020_V_2angle  \
# 0                   35.7                    3.76                   49.1
# 1                   47.2                    3.77                   50.3
# 2                   52.7                    3.78                   40.4
# 3                   34.9                    3.77                   34.9
# 4                   50.0                    3.77                   41.9
#
#    START2_OP020_V_2torque  START2_OP040_Vision_cosseprog  \
# 0                    3.78                          300.0
# 1                    3.76                           30.0
# 2                    3.78                          300.0
# 3                    3.78                         1000.0
# 4                    3.75                          400.0
#
#    START2_OP050_Vision_paliermodel  START2_OP050_Vision_palierpresencedouille  \
# 0                              1.0                                        1.0
# 1                              1.0                                        1.0
# 2                              1.0                                        1.0
# 3                              2.0                                        1.0
# 4                              1.0                                        1.0
#
#    START2_OP060_Vision_tirantcouleur  START2_OP070_V_1angle  \
# 0                                2.0                  111.7
# 1                                2.0                  106.0
# 2                                2.0                  103.4
# 3                                1.0                  146.0
# 4                                2.0                  115.8
#
#    START2_OP070_V_1prog  ...  START2_OP090_SnapRingFinalStroke  \
# 0                   8.0  ...                             11.60
# 1                   8.0  ...                             11.82
# 2                   8.0  ...                             11.86
# 3                   7.0  ...                             11.47
# 4                   8.0  ...                             11.88
#
#    START2_OP090_SnapRingMidPointForce  START2_OP090_SnapRingPeakForce  \
# 0                               71.52                          122.23
# 1                               67.38                          163.78
# 2                               89.09                          207.73
# 3                               93.45                          177.31
# 4                               85.17                          174.73
#
#    START2_OP090_StartLinePeakForce  START2_OP100_Capuchon_insertionmesure  \
# 0                            20.57                                   0.55
# 1                            18.73                                   0.55
# 2                            26.39                                   0.55
# 3                            25.73                                   0.59
# 4                            21.50                                   0.42
#
#    START2_OP110_Vissage_M8angle  START2_OP110_Vissage_M8prog  \
# 0                          34.7                          2.0
# 1                          38.7                          2.0
# 2                          30.2                          2.0
# 3                          17.6                          1.0
# 4                          52.0                          1.0
#
#    START2_OP110_Vissage_M8torque  START2_OP120_RodageI_mesure  \
# 0                           9.54                       126.96
# 1                           9.54                       133.88
# 2                           9.66                       135.28
# 3                          12.06                       116.51
# 4                          12.12                       140.92
#
#    START2_OP120_RodageU_mesure
# 0                        11.97
# 1                        11.97
# 2                        11.97
# 3                        11.97
# 4                        11.98
#
# [5 rows x 27 columns]

# %%
ytrain = pd.read_csv("valeo_ytrain.csv")
print(ytrain.shape)
ytrain.head()
# Out:
# (27586, 1)
#    Anomaly
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
ytrain["Anomaly"].value_counts() / len(ytrain)
# Out:
# 0    0.974879
# 1    0.025121
# Name: Anomaly, dtype: float64

# %%
xtest = pd.read_csv("valeo_xtest.csv")
print(xtest.shape)
xtest.head()
# Out:
# (27587, 27)
#    START2_OP020_V_1angle  START2_OP020_V_1torque  START2_OP020_V_2angle  \
# 0                   35.1                    3.78                   37.4
# 1                   35.2                    3.75                   33.2
# 2                   46.1                    3.79                   36.1
# 3                   35.0                    3.76                   43.7
# 4                   44.9                    3.76                   31.9
#
#    START2_OP020_V_2torque  START2_OP040_Vision_cosseprog  \
# 0                    3.77                          700.0
# 1                    3.75                         1300.0
# 2                    3.77                         1100.0
# 3                    3.79                         1300.0
# 4                    3.79                          700.0
#
#    START2_OP050_Vision_paliermodel  START2_OP050_Vision_palierpresencedouille  \
# 0                              2.0                                        1.0
# 1                              2.0                                        1.0
# 2                              2.0                                        1.0
# 3                              2.0                                        1.0
# 4                              2.0                                        1.0
#
#    START2_OP060_Vision_tirantcouleur  START2_OP070_V_1angle  \
# 0                                1.0                  144.1
# 1                                1.0                  153.5
# 2                                1.0                  131.1
# 3                                1.0                  147.1
# 4                                1.0                  163.1
#
#    START2_OP070_V_1prog  ...  START2_OP090_SnapRingFinalStroke  \
# 0                   7.0  ...                             11.58
# 1                   7.0  ...                             12.12
# 2                   7.0  ...                             11.92
# 3                   7.0  ...                             11.93
# 4                   7.0  ...                             11.59
#
#    START2_OP090_SnapRingMidPointForce  START2_OP090_SnapRingPeakForce  \
# 0                               78.73                          137.70
# 1                               71.78                          135.23
# 2                               67.03                          161.63
# 3                               76.06                          123.96
# 4                               62.30                          126.82
#
#    START2_OP090_StartLinePeakForce  START2_OP100_Capuchon_insertionmesure  \
# 0                            27.91                                   0.41
# 1                            16.29                                   0.23
# 2                            20.99                                   0.12
# 3                            23.47                                   0.23
# 4                            35.31                                   0.41
#
#    START2_OP110_Vissage_M8angle  START2_OP110_Vissage_M8prog  \
# 0                          15.0                          1.0
# 1                          23.8                          1.0
# 2                          16.8                          1.0
# 3                          18.5                          1.0
# 4                          13.5                          1.0
#
#    START2_OP110_Vissage_M8torque  START2_OP120_RodageI_mesure  \
# 0                          12.14                       114.68
# 1                          12.25                       120.63
# 2                          12.17                       142.24
# 3                          12.19                       116.94
# 4                          12.18                       120.41
#
#    START2_OP120_RodageU_mesure
# 0                        11.97
# 1                        11.97
# 2                        11.97
# 3                        11.97
# 4                        11.97
#
# [5 rows x 27 columns]

# %% [markdown]
# ## fit

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(loss='log', max_iter=1000, tol=1e-3, random_state=42)
sgd_clf.fit(xtrain, ytrain.values.ravel())
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='log', max_iter=1000,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=42, shuffle=True, tol=0.001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
from sklearn.linear_model import LogisticRegression
# Train the anomaly detector
clf = LogisticRegression(solver='liblinear', max_iter=1000)
clf.fit(xtrain, ytrain.values.ravel(), )
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
sscore = sgd_clf.decision_function(xtest)

# %%
sscore[:25]
# Out:
# array([-2412.79026338, -3226.07971087, -2955.53227047, -3450.34935078,
#        -2807.07754842, -1146.45788008, -1226.31699197, -1426.1963938 ,
#        -2844.87135307, -2019.16751588, -1177.52374173, -1252.21501614,
#         -959.59110695, -1112.52403858, -2496.86279595, -2916.8258124 ,
#        -1226.659192  , -2990.73408658,  -972.39584167, -2618.18697136,
#        -2292.07734504,  -473.62164213, -3220.00467363, -2612.68305906,
#        -2843.32823191])

# %% [markdown]
# ## Submission

# %%
# Save the anomaly scores to file
print(sscore.shape)
np.savetxt('ytest_challenge_student.csv', sscore, fmt = '%1.6f', delimiter=',')
# Out:
# (27587,)

# %%
pip install scikit-fda
# Out:
# Collecting scikit-fdaNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_fda-0.5-py2.py3-none-any.whl (280 kB)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (0.23.2)
# Requirement already satisfied: typing-extensions in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (3.7.4.3)
# Collecting findiff
#   Downloading findiff-0.8.9.tar.gz (26 kB)
# Collecting scikit-datasets[cran]>=0.1.24
#   Downloading scikit_datasets-0.1.38-py3-none-any.whl (30 kB)
# Requirement already satisfied: matplotlib in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (3.3.4)
# Collecting fdasrsf>=2.2.0
#   Downloading fdasrsf-2.2.2-cp37-cp37m-win_amd64.whl (404 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (1.19.5)
# Requirement already satisfied: cython in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (0.29.22)
# Requirement already satisfied: pandas in c:\users\antoi\anaconda3\lib\site-packages (from scikit-fda) (1.2.2)
# Collecting dcor
#   Downloading dcor-0.5.2-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: scipy>=1.3.0 in c:\users\antoi\appdata\roaming\python\python37\site-packages (from scikit-fda) (1.6.0)
# Collecting rdata
#   Downloading rdata-0.3-py2.py3-none-any.whl (13 kB)
# Collecting mpldatacursor
#   Downloading mpldatacursor-0.7.1-py3-none-any.whl (23 kB)
# Collecting multimethod>=1.2
#   Downloading multimethod-1.5-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (1.14.5)
# Requirement already satisfied: joblib in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (1.0.1)
# Requirement already satisfied: six in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (1.15.0)
# Requirement already satisfied: tqdm in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (4.56.0)
# Requirement already satisfied: numba in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (0.51.2)
# Requirement already satisfied: pyparsing in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (2.4.7)
# Requirement already satisfied: patsy in c:\users\antoi\anaconda3\lib\site-packages (from fdasrsf>=2.2.0->scikit-fda) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\antoi\anaconda3\lib\site-packages (from cffi>=1.0.0->fdasrsf>=2.2.0->scikit-fda) (2.20)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\antoi\anaconda3\lib\site-packages (from scikit-learn>=0.20->scikit-fda) (2.1.0)
# Requirement already satisfied: setuptools in c:\users\antoi\anaconda3\lib\site-packages (from dcor->scikit-fda) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\antoi\anaconda3\lib\site-packages (from numba->fdasrsf>=2.2.0->scikit-fda) (0.34.0)
# Requirement already satisfied: sympy in c:\users\antoi\anaconda3\lib\site-packages (from findiff->scikit-fda) (1.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\antoi\anaconda3\lib\site-packages (from matplotlib->scikit-fda) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\antoi\anaconda3\lib\site-packages (from matplotlib->scikit-fda) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\antoi\anaconda3\lib\site-packages (from matplotlib->scikit-fda) (8.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\antoi\anaconda3\lib\site-packages (from matplotlib->scikit-fda) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\antoi\anaconda3\lib\site-packages (from pandas->scikit-fda) (2021.1)
# Collecting xarray
#   Downloading xarray-0.17.0-py3-none-any.whl (759 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\antoi\anaconda3\lib\site-packages (from sympy->findiff->scikit-fda) (1.1.0)
# Building wheels for collected packages: findiff
#   Building wheel for findiff (setup.py): started
#   Building wheel for findiff (setup.py): finished with status 'done'
#   Created wheel for findiff: filename=findiff-0.8.9-py3-none-any.whl size=29218 sha256=5c5612ad008574a693d627920d29a31ae4733ab6cf50c8d672a73f6f48057e67
#   Stored in directory: c:\users\antoi\appdata\local\pip\cache\wheels\72\64\7b\009d4ccf603b1e1c1929d35c6c31071e7dca901546c2973e51
# Successfully built findiff
# Installing collected packages: xarray, scikit-datasets, rdata, multimethod, mpldatacursor, findiff, fdasrsf, dcor, scikit-fda
# Successfully installed dcor-0.5.2 fdasrsf-2.2.2 findiff-0.8.9 mpldatacursor-0.7.1 multimethod-1.5 rdata-0.3 scikit-datasets-0.1.38 scikit-fda-0.5 xarray-0.17.0
